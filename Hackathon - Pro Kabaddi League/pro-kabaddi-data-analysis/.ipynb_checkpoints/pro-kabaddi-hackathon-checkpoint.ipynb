# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
# Input data files are available in the "../data/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
# Any results you write to the current directory are saved as output.
def flatten_json(data, delim ):
    val = {}
    if isinstance(data, dict ):
        for i in data.keys():
            if isinstance(data[i], dict ):
                get = flatten_json( data[i], delim )
                for j in get.keys():
                    val[ i + delim + j ] = get[j]
            elif isinstance( data[i], list):
                for j in data[i]:
                    get = flatten_json( j, delim )
                    for k in get.keys():
                        val[ i + delim + k ] = get[k]
            else:
                val[i] = data[i]
    #else:
    #    return val[data] = dict(data)
    return val
print(pd.__version__)
# Out:
# 0.23.4

# %%
f = open('stats_team.json')
data = json.load(f)
f.close()
data = map( lambda x: flatten_json( x, "__" ), data )
df = pd.DataFrame(list(data))
df.info()
# Out:
#              bio__captain  bio__captain_id bio__captain_shortname  \
# 0   Joginder Singh Narwal              194        Joginder Narwal
# 1          Maninder Singh              143         Maninder Singh
# 2   Dharmaraj Cheralathan               42  Dharmaraj Cheralathan
# 3         Fazel Atrachali              259        Fazel Atrachali
# 4             Rohit Kumar              326            Rohit Kumar
# 5            Nitesh Kumar              725           Nitesh Kumar
# 6      Deepak Niwas Hooda               41           Deepak Hooda
# 7        PO Surjeet Singh              322          Surjeet Singh
# 8          Pardeep Narwal              197         Pardeep Narwal
# 9             Rohit Gulia              686            Rohit Gulia
# 10  Abozar Mohajermighani              489  Abozar Mohajermighani
# 11            Ajay Thakur               26            Ajay Thakur
#
#    bio__city_name              bio__coach  bio__coach_id  \
# 0           Delhi     Krishan Kumar Hooda           2466
# 1         Kolkata               BC Ramesh            812
# 2            None            Rakesh Kumar             88
# 3          Mumbai           Sanjeev Kumar            306
# 4       Bengaluru  Randhir Singh Sehrawat            128
# 5            None           Jasveer Singh           2464
# 6          Jaipur          Srinivas Reddy           2469
# 7            Pune              Anup Kumar             29
# 8           Patna         Ram Mehar Singh            808
# 9            None          Manpreet Singh            309
# 10          Vizag  Gholamreza Mazandarani           2467
# 11           None             E Bhaskaran            175
#
#       bio__coach_shortname                            bio__facebook  \
# 0            Krishan Hooda  www.facebook.com/dabangdelhikabaddiclub
# 1                BC Ramesh          www.facebook.com/bengalwarriors
# 2             Rakesh Kumar        www.facebook.com/haryanasteelers/
# 3            Sanjeev Kumar                  www.facebook.com/umumba
# 4            Randhir Singh          www.facebook.com/bengalurubulls
# 5            Jasveer Singh              www.facebook.com/yoddhahum/
# 6           Srinivas Reddy      www.facebook.com/jaipurpinkpanthers
# 7               Anup Kumar            www.facebook.com/puneripaltan
# 8                Ram Singh           www.facebook.com/patnapirates/
# 9           Manpreet Singh           www.facebook.com/Fortunegiants
# 10  Gholamreza Mazandarani        www.facebook.com/TeluguTitansTeam
# 11             E Bhaskaran         www.facebook.com/tamilthalaivas/
#
#    bio__google_plus                            bio__instagram  \
# 0              None           www.instagram.com/dabangdelhikc
# 1              None         www.instagram.com/bengal.warriors
# 2              None         www.instagram.com/haryanasteelers
# 3              None                 www.instagram.com/u_mumba
# 4              None  www.instagram.com/bengalurubullsofficial
# 5              None        www.instagram.com/officialupyoddha
# 6              None     www.instagram.com/jaipur_pinkpanthers
# 7              None    www.instagram.com/puneripaltanofficial
# 8              None          www.instagram.com/patnapirates\n
# 9              None           www.instagram.com/fortunegiants
# 10             None           www.instagram.com/telugu_titans
# 11             None          www.instagram.com/tamilthalaivas
#
#                 ...              over_all_stats__top_defender_value  \
# 0               ...                                             222
# 1               ...                                             130
# 2               ...                                              84
# 3               ...                                             181
# 4               ...                                             166
# 5               ...                                             190
# 6               ...                                             128
# 7               ...                                             149
# 8               ...                                             176
# 9               ...                                             179
# 10              ...                                             195
# 11              ...                                             110
#
#    over_all_stats__top_raider over_all_stats__top_raider_id  \
# 0                Naveen Kumar                          2296
# 1              Maninder Singh                           143
# 2              Vikash Kandola                           366
# 3                  Anup Kumar                            29
# 4                 Rohit Kumar                           326
# 5            Rishank Devadiga                            94
# 6                Jasvir Singh                            52
# 7          Deepak Niwas Hooda                            41
# 8              Pardeep Narwal                           197
# 9               Sachin Tanwar                           757
# 10            Rahul Chaudhari                            81
# 11                Ajay Thakur                            26
#
#    over_all_stats__top_raider_value over_all_stats__total_defending_points  \
# 0                               383                                   1060
# 1                               571                                   1102
# 2                               368                                    596
# 3                               489                                   1303
# 4                               562                                   1162
# 5                               310                                    646
# 6                               338                                   1163
# 7                               367                                   1255
# 8                              1073                                   1297
# 9                               433                                    702
# 10                              825                                   1157
# 11                              474                                    545
#
#    over_all_stats__total_raid_points  over_all_stats__unsuccesful_tackles  \
# 0                               2137                                 1830
# 1                               2184                                 1775
# 2                               1187                                  985
# 3                               2223                                 1644
# 4                               2267                                 1639
# 5                               1179                                  944
# 6                               2093                                 1685
# 7                               2066                                 1783
# 8                               2606                                 1926
# 9                               1160                                  785
# 10                              2224                                 1709
# 11                              1142                                  913
#
#    over_all_stats__unsuccess_raids over_all_stats__wins  \
# 0                             1146                   44
# 1                             1135                   54
# 2                              587                   30
# 3                             1129                   77
# 4                             1237                   57
# 5                              648                   27
# 6                             1209                   52
# 7                             1224                   49
# 8                             1214                   68
# 9                              657                   39
# 10                            1117                   49
# 11                             623                   14
#
#     over_all_stats__yellow_cards
# 0                              1
# 1                              1
# 2                              0
# 3                              6
# 4                              5
# 5                              2
# 6                              4
# 7                             11
# 8                              6
# 9                              2
# 10                             3
# 11                             2
#
# [12 rows x 172 columns]
