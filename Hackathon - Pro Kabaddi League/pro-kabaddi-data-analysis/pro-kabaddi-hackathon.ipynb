# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
import csv
import re

from flatten_json import flatten
from pandas.io.json import json_normalize


# Until fuction: line seperator
def print_dashes_and_ln():
    print('-'*100, '\n')
    
# Formatter to display all float format in 2 decimal format
#pd.options.display.float_format = '{:.2f}'.format

import warnings
warnings.filterwarnings('ignore')

# %%
f = open('stats_match.json')
data = json.load(f)
f.close()
data_flattened = [flatten(d) for d in data]
print(data_flattened)
team_df = pd.DataFrame(data_flattened)
#team_df.replace([], None)
#columns = [column for column in df.columns]
team_df = team_df[team_df.astype(str) != '[]']



#print(type(data))
#df = pd.Series(flatten_json(data,"__")).to_frame()
#df
#data = map( lambda x: flatten_json( x, "__" ), data )
#print(list(data.get('stat_team')))
#team_df = pd.DataFrame(data)

#Remove Columns with only One Value
team_df = team_df.loc[:,team_df.apply(pd.Series.nunique) > 1]
team_df
# Drop unwanted columns
#columns_to_drop =['bio__facebook','bio__instagram','bio__official_website']
#team_df.drop(columns_to_drop, inplace=True, axis = 1)

# Only drop columns which have at least 50% non-NaNs
#team_df.dropna(thresh=int(team_df.shape[0] * .5), inplace=True, axis=1)

#team_df.rename(columns=lambda x: x.replace('over_all_stats__', 'team_'), inplace=True)
#team_df.rename(columns=lambda x: x.replace('bio__', 'team_'), inplace=True)

#column for column in df.columns column.contains('over_all_stats__')
#print(df['team_max_win_margin__match_id'])
#print(df['team_highest_score__match_id'])
#df
#team_df.head()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#     events_event_0_clock  events_event_0_defender_id  \
# 0                  20:00                         NaN
# 1                  20:00                         NaN
# 2                  19:58                         NaN
# 3                  20:00                         NaN
# 4                  19:58                         NaN
# 5                  19:59                         NaN
# 6                  20:00                         NaN
# 7                  20:00                         NaN
# 8                  20:00                         NaN
# 9                  19:59                      2486.0
# ...

# %%
f = open('stats_player.json')
data = json.load(f)
f.close()
data = map( lambda x: flatten_json( x, "__" ), data )
player_df = pd.DataFrame(list(data))

#Remove Columns with only One Value
player_df = player_df.loc[:,player_df.apply(pd.Series.nunique) > 1]

# Drop unwanted columns
#columns_to_drop =['player_has_additional_details','player_height','player_is_captain']
#df.drop(columns_to_drop, inplace=True, axis = 1)

# Only drop columns which have at least 50% non-NaNs
player_df.dropna(thresh=int(player_df.shape[0] * .5), inplace=True, axis=1)

player_df.rename(columns=lambda x: x.replace('over_all_stats__', 'player_'), inplace=True)
player_df.rename(columns=lambda x: x.replace('bio__', 'player_'), inplace=True)


#null_counts = player_df.isnull().sum()
#null_counts
# Drop any rows which have any nans
#df.player_player_id.dropna(inplace=True)
player_df
# Out:
#     player_date_of_birth           player_full_name  \
# 0            Oct 30 1992             Takamitsu Kono
# 1            Jul 11 1986               Dong Ju Hong
# 2            Nov  6 1992               Jang Kun Lee
# 3            Jul  5 1985            Seong Ryeol Kim
# 4            Apr  1 1984               Tae Deok Eom
# 5            Jan  6 1984            Sanjay Shrestha
# 6                    NaN                        NaN
# 7            May  1 1986                Ajay Thakur
# 8            Apr  4 1991        Amit Singh Chhillar
# 9            Nov 20 1983                 Anup Kumar
# 10           Nov 11 1991            Bhupender Singh
# 11           Jun  7 1991            Chandran Ranjit
# 12           Jun 10 1994         Deepak Niwas Hooda
# 13           Apr 21 1975      Dharmaraj Cheralathan
# 14           Feb  3 1994           Dharmendra Singh
# 15           Jun  8 1993         Gangadhari Mallesh
# 16           Mar 14 1995            Gurvinder Singh
# ...

# %%
f = open('stats_squad.json')
data = json.load(f)
f.close()
data = map( lambda x: flatten_json( x, "__" ), data )
team_df = pd.DataFrame(list(data))

#Remove Columns with only One Value
#team_df = team_df.loc[:,team_df.apply(pd.Series.nunique) > 1]

# Drop unwanted columns
#columns_to_drop =['bio__facebook','bio__instagram','bio__official_website']
#team_df.drop(columns_to_drop, inplace=True, axis = 1)

# Only drop columns which have at least 50% non-NaNs
#team_df.dropna(thresh=int(team_df.shape[0] * .5), inplace=True, axis=1)

#team_df.rename(columns=lambda x: x.replace('over_all_stats__', 'team_'), inplace=True)
#team_df.rename(columns=lambda x: x.replace('bio__', 'team_'), inplace=True)

#column for column in df.columns column.contains('over_all_stats__')
#print(df['team_max_win_margin__match_id'])
#print(df['team_highest_score__match_id'])
#df
team_df
# Out:
#    language_lookup__country_id language_lookup__country_name  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# 5                          NaN                           NaN
# 6                          NaN                           NaN
# 7                          NaN                           NaN
# 8                          NaN                           NaN
# 9                          NaN                           NaN
# 10                         NaN                           NaN
# 11                         NaN                           NaN
# 12                  Country Id                  Country Name
# 13                  Country Id                  Country Name
# ...
